# %%
Hardware vs Software

Hardware: Physical parts of a computer that you can see and touch.
Example: Keyboard
Software: Programs or instructions that tell the computer what to do.
Example: Operating System (like Windows)

Key Difference:
Hardware is the physical device, while software is the set of instructions that runs on the hardware.
